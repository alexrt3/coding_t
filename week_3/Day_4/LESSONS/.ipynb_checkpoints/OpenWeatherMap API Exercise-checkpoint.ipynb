# %%
# OpenweatherMap API

# https://openweathermap.org

# %%
# API/Developer

# Sign Up for account

# Find Where API key is

# Attach the API key to EVERY single API call

# Look up API documentation for the current forecast

# Find out how to make an API call

# Current weather conditions
# Today's High Temperature
# Current Temperature
# Today's Low Temperature
# Humidity
# City, State


from IPython.display import clear_output as co
import json
import requests


class Weather:
    def __init__(self, city, city_id, state, high, low, current, humidity):
        self.city = city
        self.city_id = city_id
        self.state = state
        self.high = high
        self.low = low
        self.current = current
        self.humidity = humidity

    def get_city(self):
        return self.city

    def get_city_id(self):
        return self.city_id

    def get_high(self):
        return self.high

    def get_low(self):
        return self.low

    def get_current(self):
        return self.current
    
    def get_humidity(self):
        return self.humidity

    def __repr__(self):
        return f'<Weather: {self.high} {self.city}>'

    def __str__(self):
        return f'{self.high} {self.city}'

    # @classmethod
    def all(self):
        print("+:"*25)
        print(f'The weather in {(self.name).title()},{(self.state)} is:')
        print(f'Current: {(self.current)}')
        print(f'With a high of: {(self.high)} and a low of {(self.low)}.')
        print(f'The humidity is: {(self.humidity)}.')
        print(":+"*25)


class WeatherDex:
    def __init__(self, name):
        self.web_link = f'api.openweathermap.org/data/2.5/weather?q={city_name},{state_code},{country_code}&appid=b5e21d8e54975d090069c0667cfd02d1'

    def run(self):
        url = requests.get(self.web_link)
        if url.status_code == 400:
            print('You must pass in a valid City Name to execute this program.')
        elif url.status_code == 200:
            data = url.json()
        Current = data['abilities'][0]['ability']['name']
            City = data['forms'][0]['name']
            High = data['types'][0]['type']['name']
            Low = data['weight']
            w = Weather(city, state, high, low, current, humidity)
            w.all()
